# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
import pandas as pd

df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv', low_memory=False)
df['Created Date'] = pd.to_datetime(df['Created Date'], format='mixed')
df['Closed Date'] = pd.to_datetime(df['Closed Date'], format='mixed', errors='coerce')
df['Request_Closing_Time'] = df['Closed Date'] - df['Created Date']
df['Request_Closing_Time'] = df['Request_Closing_Time'].fillna('No closing time')
print(df[['Created Date', 'Closed Date', 'Request_Closing_Time']].head())
# Out:
#          Created Date         Closed Date Request_Closing_Time
# 0 2015-12-31 23:59:45 2016-01-01 00:55:00      0 days 00:55:15
# 1 2015-12-31 23:59:44 2016-01-01 01:26:00      0 days 01:26:16
# 2 2015-12-31 23:59:29 2016-01-01 04:51:00      0 days 04:51:31
# 3 2015-12-31 23:57:46 2016-01-01 07:43:00      0 days 07:45:14
# 4 2015-12-31 23:56:58 2016-01-01 03:24:00      0 days 03:27:02

# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.drop(['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 
         'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number',
         'School Region','School Code','School Phone Number','School Address','School City','School State','School Zip',
         'School Not Found','School or Citywide Complaint','Vehicle Type', 'Taxi Company Borough','Taxi Pick Up Location',
         'Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction',
         'Ferry Terminal Name','Landmark','X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date',
         'Community Board','Facility Type','Location'], axis=1, inplace =True )
df.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#             Complaint Type                    Descriptor    Location Type  \
# 0  Noise - Street/Sidewalk              Loud Music/Party  Street/Sidewalk
# 1         Blocked Driveway                     No Access  Street/Sidewalk
# 2         Blocked Driveway                     No Access  Street/Sidewalk
# 3          Illegal Parking  Commercial Overnight Parking  Street/Sidewalk
# 4          Illegal Parking              Blocked Sidewalk  Street/Sidewalk
#
#    Incident Zip      City  Status  \
# 0       10034.0  NEW YORK  Closed
# 1       11105.0   ASTORIA  Closed
# 2       10458.0     BRONX  Closed
# ...

# %%
df.isna().sum()
df.dropna(inplace=True)
print(df)
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM           01-01-16 0:55   NYPD
# 1         32309934  12/31/2015 11:59:44 PM           01-01-16 1:26   NYPD
# 2         32309159  12/31/2015 11:59:29 PM           01-01-16 4:51   NYPD
# 3         32305098  12/31/2015 11:57:46 PM           01-01-16 7:43   NYPD
# 4         32306529  12/31/2015 11:56:58 PM           01-01-16 3:24   NYPD
# ...            ...                     ...                     ...    ...
# 300692    30281370  03/29/2015 12:34:32 AM  03/29/2015 01:13:01 AM   NYPD
# 300694    30281230  03/29/2015 12:33:28 AM  03/29/2015 02:33:59 AM   NYPD
# 300695    30283424  03/29/2015 12:33:03 AM  03/29/2015 03:40:20 AM   NYPD
# 300696    30280004  03/29/2015 12:33:02 AM  03/29/2015 04:38:35 AM   NYPD
# 300697    30281825  03/29/2015 12:33:01 AM  03/29/2015 04:41:50 AM   NYPD
#
#                  Complaint Type                    Descriptor  \
# ...

# %%
for columns in df.columns:
    print("The number of values in", columns, "are")
    unique_values=(df[columns].unique())
    unique_values_up =pd.DataFrame(unique_values)
    print(unique_values_up)
# Out:
# The number of values in Unique Key are
#                0
# 0       32310363
# 1       32309934
# 2       32309159
# 3       32305098
# 4       32306529
# ...          ...
# 291102  30281370
# 291103  30281230
# 291104  30283424
# 291105  30280004
# 291106  30281825
#
# [291107 rows x 1 columns]
# The number of values in Created Date are
#                              0
# 0       12/31/2015 11:59:45 PM
# 1       12/31/2015 11:59:44 PM
# 2       12/31/2015 11:59:29 PM
# 3       12/31/2015 11:57:46 PM
# 4       12/31/2015 11:56:58 PM
# ...                        ...
# 251965  03/29/2015 12:34:32 AM
# 251966  03/29/2015 12:33:28 AM
# 251967  03/29/2015 12:33:03 AM
# 251968  03/29/2015 12:33:02 AM
# 251969  03/29/2015 12:33:01 AM
#
# [251970 rows x 1 columns]
# The number of values in Closed Date are
#                              0
# 0                01-01-16 0:55
# 1                01-01-16 1:26
# 2                01-01-16 4:51
# 3                01-01-16 7:43
# ...

# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.drop(['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 
         'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number',
         'School Region','School Code','School Phone Number','School Address','School City','School State','School Zip',
         'School Not Found','School or Citywide Complaint','Vehicle Type', 'Taxi Company Borough','Taxi Pick Up Location',
         'Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction',
         'Ferry Terminal Name','Landmark','X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date',
         'Community Board','Facility Type','Location'], axis=1, inplace =True )
numdf = df.select_dtypes(include=['number'])
print("sum", numdf.sum())
# Out:
# sum Unique Key      9.412008e+12
# Incident Zip    3.233869e+09
# Latitude        1.210202e+07
# Longitude      -2.196759e+07
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.drop(['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 
         'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number',
         'School Region','School Code','School Phone Number','School Address','School City','School State','School Zip',
         'School Not Found','School or Citywide Complaint','Vehicle Type', 'Taxi Company Borough','Taxi Pick Up Location',
         'Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction',
         'Ferry Terminal Name','Landmark','X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date',
         'Community Board','Facility Type','Location'], axis=1, inplace =True )
numdf = df.select_dtypes(include=['number'])
df.dropna(inplace = True)
print("mean", numdf.mean())
# Out:
# mean Unique Key      3.130054e+07
# Incident Zip    1.084889e+04
# Latitude        4.072588e+01
# Longitude      -7.392563e+01
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.drop(['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 
         'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number',
         'School Region','School Code','School Phone Number','School Address','School City','School State','School Zip',
         'School Not Found','School or Citywide Complaint','Vehicle Type', 'Taxi Company Borough','Taxi Pick Up Location',
         'Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction',
         'Ferry Terminal Name','Landmark','X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date',
         'Community Board','Facility Type','Location'], axis=1, inplace =True )
numdf = df.select_dtypes(include=['number'])
print("Standard Deviation", numdf.std())
# Out:
# Standard Deviation Unique Key      573854.692971
# Incident Zip       583.182081
# Latitude             0.082012
# Longitude            0.078454
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.drop(['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 
         'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number',
         'School Region','School Code','School Phone Number','School Address','School City','School State','School Zip',
         'School Not Found','School or Citywide Complaint','Vehicle Type', 'Taxi Company Borough','Taxi Pick Up Location',
         'Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction',
         'Ferry Terminal Name','Landmark','X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date',
         'Community Board','Facility Type','Location'], axis=1, inplace =True )
numdf = df.select_dtypes(include=['number'])
print("skewness", numdf.skew())
# Out:
# skewness Unique Key      0.020283
# Incident Zip   -2.448212
# Latitude        0.116736
# Longitude      -0.291343
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv',low_memory = False)
df.drop(['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 
         'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number',
         'School Region','School Code','School Phone Number','School Address','School City','School State','School Zip',
         'School Not Found','School or Citywide Complaint','Vehicle Type', 'Taxi Company Borough','Taxi Pick Up Location',
         'Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction',
         'Ferry Terminal Name','Landmark','X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date',
         'Community Board','Facility Type','Location'], axis=1, inplace =True )
numdf = df.select_dtypes(include=['number'])
print("kurtosis\n", numdf.kurt())
# Out:
# kurtosis
#  Unique Key      -1.169387
# Incident Zip    35.992081
# Latitude        -0.718893
# Longitude        1.441588
# dtype: float64

# %%
import pandas as pd
corr = df.corr(numeric_only=True)
corr
# Out:
#               Unique Key  Incident Zip  Latitude  Longitude
# Unique Key      1.000000      0.024840 -0.032243  -0.009180
# Incident Zip    0.024840      1.000000 -0.498488   0.391383
# Latitude       -0.032243     -0.498488  1.000000   0.364966
# Longitude      -0.009180      0.391383  0.364966   1.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd

corr = df.corr(numeric_only=True)

plt.figure(figsize=(8, 6))
plt.imshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(label='Correlation Coefficient')
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
complaints = df['Complaint Type'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
plt.barh(complaints.index, complaints.values, color='skyblue')
plt.title('Top 10 complaints')
plt.xlabel('Number of Complaints')
plt.ylabel('type of complaint')
X = complaints.index
y = complaints.values
plt.bar
plt.show
plt.savefig('top_10_complaints ')

# %%
from matplotlib import pyplot as plt
borough_value = df['Borough'].value_counts()
plt.pie(borough_value,labels=borough_value.index)
plt.title('Complaintes through Borough')
plt.show()

# %%
from matplotlib import pyplot as plt
most_complaints = df['Complaint Type'].value_counts().head(5)
plt.figure(figsize=(12, 6))
plt.plot(most_complaints)
plt.title('Top 5 complaint Types')
plt.xlabel('Complaint Types')
plt.ylabel('Num of complaints')
plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
df = pd.read_csv('Customer Service_Requests_from_2010_to_Present.csv', low_memory=False)
zip_complaint = df['Incident Zip'].dropna().astype(int)
plt.figure(figsize=(18, 6))
n, bins, patches = plt.hist(zip_complaint, bins=40, color='indigo', edgecolor='black')
plt.xticks(bins, rotation=45)
plt.title('Distribution of Complaints Across ZIP Codes')
plt.xlabel('ZIP Code')
plt.ylabel('Number of Complaints')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Created Date'] = pd.to_datetime(df['Created Date'], errors='coerce')
df['Closed Date'] = pd.to_datetime(df['Closed Date'], errors='coerce')
df['Request_Closing_Time'] = df['Closed Date'] - df['Created Date']
df = df.dropna(subset=['Request_Closing_Time'])
df = df[df['Request_Closing_Time'] >= pd.Timedelta(0)]
grouped = df.groupby(['Complaint Type', 'Location Type'])['Request_Closing_Time'].mean().reset_index()
top10 = grouped.sort_values('Request_Closing_Time', ascending=False).head(10)
plt.figure(figsize=(14, 6))
plt.barh(top10['Complaint Type'] + " at " + top10['Location Type'],top10['Request_Closing_Time'].dt.total_seconds() / 3600,color='indigo')
plt.xlabel('Avg Closing Time (hours)')
plt.title('10 most complaints through location with highest closing time by location')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
df['Created Date'] = pd.to_datetime(df['Created Date'],format = 'mixed')
df['Closed Date'] = pd.to_datetime(df['Closed Date'],format = 'mixed', errors='coerce')
df = df.dropna(subset=['Created Date', 'Closed Date'])
df['Closing_Time'] = df['Closed Date'] - df['Created Date']
df = df[df['Closing_Time'] > pd.Timedelta(0)]
df['Hours_Taken'] = df['Closing_Time'].dt.total_seconds() / 3600
top5 = df['Complaint Type'].value_counts().head(5).index
filtered_df = df[df['Complaint Type'].isin(top5)]
avg_times = filtered_df.groupby('Complaint Type')['Hours_Taken'].mean()
max_avg = avg_times.max()
min_avg = avg_times.min()
threshold = 0.05 
if max_avg - min_avg > threshold:
    print("Reject the null hypothesis (H0): The average response time differs across complaint types")
else:
    print("Fail to reject the null hypothesis (H0): The average response time is similar across complaint types.")
# Out:
# Reject the null hypothesis (H0): The average response time differs across complaint types.

# %%
import pandas as pd
from scipy.stats import chi2_contingency
top5 = df['Complaint Type'].value_counts().head(5).index
filtered_df = df[df['Complaint Type'].isin(top5)]
contingency_table = pd.crosstab(filtered_df['Complaint Type'], filtered_df['Location'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
if p_value <= 0.05:
    print(f"Reject the null hypothesis (H0): The type of complaint and location are related. p-value = {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H0): The type of complaint and location are independent. p-value = {p_value:.4f}")
# Out:
# Reject the null hypothesis (H0): The type of complaint and location are related. p-value = 0.0000
